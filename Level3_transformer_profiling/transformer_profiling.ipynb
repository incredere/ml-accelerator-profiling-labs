# %% [markdown]
# # Transformer Profiling Lab
#
# This notebook profiles a GPT-2 model using PyTorch Profiler to understand GPU performance.

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install transformers datasets

# %%
import torch
from transformers import GPT2Tokenizer, GPT2ForSequenceClassification
from torch.profiler import profile, record_function, ProfilerActivity
import json

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# %%
# Load GPT-2 small for sequence classification
model = GPT2ForSequenceClassification.from_pretrained('gpt2', num_labels=2)
model.to(device)
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
tokenizer.pad_token = tokenizer.eos_token

# %%
# Dummy dataset
texts = ['This is positive', 'This is negative'] * 50
labels = [1, 0] * 50

inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True)
inputs = {k: v.to(device) for k, v in inputs.items()}
labels = torch.tensor(labels).to(device)

# %%
# Profile the training
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
criterion = torch.nn.CrossEntropyLoss()

with profile(activities=[ProfilerActivity.CPU, ProfilerActivity.CUDA], record_shapes=True) as prof:
    with record_function('model_training'):
        model.train()
        for epoch in range(1):
            optimizer.zero_grad()
            outputs = model(**inputs, labels=labels)
            loss = outputs.loss
            loss.backward()
            optimizer.step()
            print(f'Loss: {loss.item()}')

print(prof.key_averages().table(sort_by='cuda_time_total', row_limit=10))

# %%
# Export trace
prof.export_chrome_trace('gpt2.pt.trace.json')
print('Trace exported to gpt2.pt.trace.json')
